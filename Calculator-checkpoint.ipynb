# %%
from PyQt6 import QtCore, QtGui, QtWidgets


class Ui_MainWindow(object):
    def setupUi(self, MainWindow):
        MainWindow.setObjectName("MainWindow")
        MainWindow.resize(443, 600)
        MainWindow.setStyleSheet("background-color: rgb(255, 255, 255);")
        self.centralwidget = QtWidgets.QWidget(parent=MainWindow)
        self.centralwidget.setObjectName("centralwidget")
        self.verticalLayout = QtWidgets.QVBoxLayout(self.centralwidget)
        self.verticalLayout.setObjectName("verticalLayout")
        self.gridLayout = QtWidgets.QGridLayout()
        self.gridLayout.setObjectName("gridLayout")
        self.push_9 = QtWidgets.QPushButton(parent=self.centralwidget)
        sizePolicy = QtWidgets.QSizePolicy(QtWidgets.QSizePolicy.Policy.MinimumExpanding, QtWidgets.QSizePolicy.Policy.Preferred)
        sizePolicy.setHorizontalStretch(0)
        sizePolicy.setVerticalStretch(10)
        sizePolicy.setHeightForWidth(self.push_9.sizePolicy().hasHeightForWidth())
        self.push_9.setSizePolicy(sizePolicy)
        self.push_9.setStyleSheet("QPushButton{\n"
"font: 75 25pt \"Segoe UI Variable Text\";\n"
"    color: rgb(255, 255, 255);\n"
"    \n"
"    background-color: rgb(81, 70, 25);\n"
"border-radius:18px;\n"
"}\n"
"QPushButton:hover{\n"
"color: rgb(0, 0, 0);\n"
"    \n"
"    background-color: rgb(95, 234, 255);\n"
"}\n"
"QPushButton{\n"
"    \n"
"    \n"
"    \n"
"    background-color: rgb(242, 248, 252);\n"
"    \n"
"    color: rgb(0, 0, 0);\n"
"}")
        self.push_9.setObjectName("push_9")
        self.gridLayout.addWidget(self.push_9, 5, 2, 1, 1)
        self.push_8 = QtWidgets.QPushButton(parent=self.centralwidget)
        sizePolicy = QtWidgets.QSizePolicy(QtWidgets.QSizePolicy.Policy.MinimumExpanding, QtWidgets.QSizePolicy.Policy.Preferred)
        sizePolicy.setHorizontalStretch(0)
        sizePolicy.setVerticalStretch(10)
        sizePolicy.setHeightForWidth(self.push_8.sizePolicy().hasHeightForWidth())
        self.push_8.setSizePolicy(sizePolicy)
        self.push_8.setStyleSheet("QPushButton{\n"
"font: 75 25pt \"Segoe UI Variable Text\";\n"
"    color: rgb(255, 255, 255);\n"
"    \n"
"    background-color: rgb(81, 70, 25);\n"
"border-radius:18px;\n"
"}\n"
"QPushButton:hover{\n"
"color: rgb(0, 0, 0);\n"
"    \n"
"    background-color: rgb(95, 234, 255);\n"
"}\n"
"QPushButton{\n"
"    \n"
"    \n"
"    \n"
"    background-color: rgb(242, 248, 252);\n"
"    \n"
"    color: rgb(0, 0, 0);\n"
"}")
        self.push_8.setObjectName("push_8")
        self.gridLayout.addWidget(self.push_8, 5, 1, 1, 1)
        self.push_4 = QtWidgets.QPushButton(parent=self.centralwidget)
        sizePolicy = QtWidgets.QSizePolicy(QtWidgets.QSizePolicy.Policy.MinimumExpanding, QtWidgets.QSizePolicy.Policy.Preferred)
        sizePolicy.setHorizontalStretch(0)
        sizePolicy.setVerticalStretch(10)
        sizePolicy.setHeightForWidth(self.push_4.sizePolicy().hasHeightForWidth())
        self.push_4.setSizePolicy(sizePolicy)
        self.push_4.setStyleSheet("QPushButton{\n"
"font: 75 25pt \"Segoe UI Variable Text\";\n"
"    color: rgb(255, 255, 255);\n"
"    \n"
"    background-color: rgb(81, 70, 25);\n"
"border-radius:18px;\n"
"}\n"
"QPushButton:hover{\n"
"color: rgb(0, 0, 0);\n"
"    \n"
"    background-color: rgb(95, 234, 255);\n"
"}\n"
"QPushButton{\n"
"    \n"
"    \n"
"    \n"
"    background-color: rgb(242, 248, 252);\n"
"    \n"
"    color: rgb(0, 0, 0);\n"
"}")
        self.push_4.setObjectName("push_4")
        self.gridLayout.addWidget(self.push_4, 3, 0, 1, 1)
        self.push_5 = QtWidgets.QPushButton(parent=self.centralwidget)
        sizePolicy = QtWidgets.QSizePolicy(QtWidgets.QSizePolicy.Policy.MinimumExpanding, QtWidgets.QSizePolicy.Policy.Preferred)
        sizePolicy.setHorizontalStretch(0)
        sizePolicy.setVerticalStretch(10)
        sizePolicy.setHeightForWidth(self.push_5.sizePolicy().hasHeightForWidth())
        self.push_5.setSizePolicy(sizePolicy)
        self.push_5.setStyleSheet("QPushButton{\n"
"font: 75 25pt \"Segoe UI Variable Text\";\n"
"    color: rgb(255, 255, 255);\n"
"    \n"
"    background-color: rgb(81, 70, 25);\n"
"border-radius:18px;\n"
"}\n"
"QPushButton:hover{\n"
"color: rgb(0, 0, 0);\n"
"    \n"
"    background-color: rgb(95, 234, 255);\n"
"}\n"
"QPushButton{\n"
"    \n"
"    \n"
"    \n"
"    background-color: rgb(242, 248, 252);\n"
"    \n"
"    color: rgb(0, 0, 0);\n"
"}")
        self.push_5.setObjectName("push_5")
        self.gridLayout.addWidget(self.push_5, 3, 1, 1, 1)
        self.push_2 = QtWidgets.QPushButton(parent=self.centralwidget)
        sizePolicy = QtWidgets.QSizePolicy(QtWidgets.QSizePolicy.Policy.MinimumExpanding, QtWidgets.QSizePolicy.Policy.Preferred)
        sizePolicy.setHorizontalStretch(0)
        sizePolicy.setVerticalStretch(10)
        sizePolicy.setHeightForWidth(self.push_2.sizePolicy().hasHeightForWidth())
        self.push_2.setSizePolicy(sizePolicy)
        self.push_2.setStyleSheet("QPushButton{\n"
"font: 75 25pt \"Segoe UI Variable Text\";\n"
"    color: rgb(255, 255, 255);\n"
"    \n"
"    background-color: rgb(81, 70, 25);\n"
"border-radius:18px;\n"
"}\n"
"QPushButton:hover{\n"
"color: rgb(0, 0, 0);\n"
"    \n"
"    background-color: rgb(95, 234, 255);\n"
"}\n"
"QPushButton{\n"
"    \n"
"    \n"
"    \n"
"    background-color: rgb(242, 248, 252);\n"
"    \n"
"    color: rgb(0, 0, 0);\n"
"}")
        self.push_2.setObjectName("push_2")
        self.gridLayout.addWidget(self.push_2, 2, 1, 1, 1)
        self.push_3 = QtWidgets.QPushButton(parent=self.centralwidget)
        sizePolicy = QtWidgets.QSizePolicy(QtWidgets.QSizePolicy.Policy.MinimumExpanding, QtWidgets.QSizePolicy.Policy.Preferred)
        sizePolicy.setHorizontalStretch(0)
        sizePolicy.setVerticalStretch(10)
        sizePolicy.setHeightForWidth(self.push_3.sizePolicy().hasHeightForWidth())
        self.push_3.setSizePolicy(sizePolicy)
        self.push_3.setStyleSheet("QPushButton{\n"
"font: 75 25pt \"Segoe UI Variable Text\";\n"
"    color: rgb(255, 255, 255);\n"
"    \n"
"    background-color: rgb(81, 70, 25);\n"
"border-radius:18px;\n"
"}\n"
"QPushButton:hover{\n"
"color: rgb(0, 0, 0);\n"
"    \n"
"    background-color: rgb(95, 234, 255);\n"
"}\n"
"QPushButton{\n"
"    \n"
"    \n"
"    \n"
"    background-color: rgb(242, 248, 252);\n"
"    \n"
"    color: rgb(0, 0, 0);\n"
"}")
        self.push_3.setObjectName("push_3")
        self.gridLayout.addWidget(self.push_3, 2, 2, 1, 1)
        self.push_7 = QtWidgets.QPushButton(parent=self.centralwidget)
        sizePolicy = QtWidgets.QSizePolicy(QtWidgets.QSizePolicy.Policy.MinimumExpanding, QtWidgets.QSizePolicy.Policy.Preferred)
        sizePolicy.setHorizontalStretch(0)
        sizePolicy.setVerticalStretch(10)
        sizePolicy.setHeightForWidth(self.push_7.sizePolicy().hasHeightForWidth())
        self.push_7.setSizePolicy(sizePolicy)
        self.push_7.setStyleSheet("QPushButton{\n"
"font: 75 25pt \"Segoe UI Variable Text\";\n"
"    color: rgb(255, 255, 255);\n"
"    \n"
"    background-color: rgb(81, 70, 25);\n"
"border-radius:18px;\n"
"}\n"
"QPushButton:hover{\n"
"color: rgb(0, 0, 0);\n"
"    \n"
"    background-color: rgb(95, 234, 255);\n"
"}\n"
"QPushButton{\n"
"    \n"
"    \n"
"    \n"
"    background-color: rgb(242, 248, 252);\n"
"    \n"
"    color: rgb(0, 0, 0);\n"
"}")
        self.push_7.setObjectName("push_7")
        self.gridLayout.addWidget(self.push_7, 5, 0, 1, 1)
        self.push_6 = QtWidgets.QPushButton(parent=self.centralwidget)
        sizePolicy = QtWidgets.QSizePolicy(QtWidgets.QSizePolicy.Policy.MinimumExpanding, QtWidgets.QSizePolicy.Policy.Preferred)
        sizePolicy.setHorizontalStretch(0)
        sizePolicy.setVerticalStretch(10)
        sizePolicy.setHeightForWidth(self.push_6.sizePolicy().hasHeightForWidth())
        self.push_6.setSizePolicy(sizePolicy)
        self.push_6.setStyleSheet("QPushButton{\n"
"font: 75 25pt \"Segoe UI Variable Text\";\n"
"    color: rgb(255, 255, 255);\n"
"    \n"
"    background-color: rgb(81, 70, 25);\n"
"border-radius:18px;\n"
"}\n"
"QPushButton:hover{\n"
"color: rgb(0, 0, 0);\n"
"    \n"
"    background-color: rgb(95, 234, 255);\n"
"}\n"
"QPushButton{\n"
"    \n"
"    \n"
"    \n"
"    background-color: rgb(242, 248, 252);\n"
"    \n"
"    color: rgb(0, 0, 0);\n"
"}")
        self.push_6.setObjectName("push_6")
        self.gridLayout.addWidget(self.push_6, 3, 2, 1, 1)
        self.pushButton = QtWidgets.QPushButton(parent=self.centralwidget)
        sizePolicy = QtWidgets.QSizePolicy(QtWidgets.QSizePolicy.Policy.MinimumExpanding, QtWidgets.QSizePolicy.Policy.Preferred)
        sizePolicy.setHorizontalStretch(0)
        sizePolicy.setVerticalStretch(10)
        sizePolicy.setHeightForWidth(self.pushButton.sizePolicy().hasHeightForWidth())
        self.pushButton.setSizePolicy(sizePolicy)
        self.pushButton.setStyleSheet("QPushButton{\n"
"font: 75 25pt \"Segoe UI Variable Text\";\n"
"    color: rgb(255, 255, 255);\n"
"    \n"
"    background-color: rgb(81, 70, 25);\n"
"border-radius:18px;\n"
"}\n"
"QPushButton:hover{\n"
"color: rgb(0, 0, 0);\n"
"    \n"
"    background-color: rgb(95, 234, 255);\n"
"}\n"
"QPushButton{\n"
"    \n"
"    \n"
"    \n"
"    background-color: rgb(242, 248, 252);\n"
"    \n"
"    color: rgb(0, 0, 0);\n"
"}")
        self.pushButton.setObjectName("pushButton")
        self.gridLayout.addWidget(self.pushButton, 2, 0, 1, 1)
        self.label = QtWidgets.QLabel(parent=self.centralwidget)
        sizePolicy = QtWidgets.QSizePolicy(QtWidgets.QSizePolicy.Policy.MinimumExpanding, QtWidgets.QSizePolicy.Policy.Preferred)
        sizePolicy.setHorizontalStretch(0)
        sizePolicy.setVerticalStretch(10)
        sizePolicy.setHeightForWidth(self.label.sizePolicy().hasHeightForWidth())
        self.label.setSizePolicy(sizePolicy)
        self.label.setStyleSheet("font: 75 36pt \"Segoe UI Variable Text\"\n"
"rgb(255, 255, 255);\n"
"\n"
"")
        self.label.setObjectName("")
        self.gridLayout.addWidget(self.label, 0, 0, 1, 4)
        self.push_0 = QtWidgets.QPushButton(parent=self.centralwidget)
        sizePolicy = QtWidgets.QSizePolicy(QtWidgets.QSizePolicy.Policy.MinimumExpanding, QtWidgets.QSizePolicy.Policy.Preferred)
        sizePolicy.setHorizontalStretch(0)
        sizePolicy.setVerticalStretch(10)
        sizePolicy.setHeightForWidth(self.push_0.sizePolicy().hasHeightForWidth())
        self.push_0.setSizePolicy(sizePolicy)
        self.push_0.setStyleSheet("QPushButton{\n"
"font: 75 25pt \"Segoe UI Variable Text\";\n"
"    color: rgb(255, 255, 255);\n"
"    \n"
"    background-color: rgb(81, 70, 25);\n"
"border-radius:18px;\n"
"}\n"
"QPushButton:hover{\n"
"color: rgb(0, 0, 0);\n"
"    \n"
"    background-color: rgb(95, 234, 255);\n"
"}\n"
"QPushButton{\n"
"    \n"
"    \n"
"    \n"
"    background-color: rgb(242, 248, 252);\n"
"    \n"
"    color: rgb(0, 0, 0);\n"
"}")
        self.push_0.setObjectName("push_0")
        self.gridLayout.addWidget(self.push_0, 6, 0, 1, 1)
        self.Dot = QtWidgets.QPushButton(parent=self.centralwidget)
        sizePolicy = QtWidgets.QSizePolicy(QtWidgets.QSizePolicy.Policy.MinimumExpanding, QtWidgets.QSizePolicy.Policy.Preferred)
        sizePolicy.setHorizontalStretch(0)
        sizePolicy.setVerticalStretch(10)
        sizePolicy.setHeightForWidth(self.Dot.sizePolicy().hasHeightForWidth())
        self.Dot.setSizePolicy(sizePolicy)
        self.Dot.setStyleSheet("QPushButton{\n"
"font: 75 25pt \"Segoe UI Variable Text\";\n"
"    color: rgb(255, 255, 255);\n"
"    \n"
"    background-color: rgb(81, 70, 25);\n"
"border-radius:18px;\n"
"}\n"
"QPushButton:hover{\n"
"color: rgb(0, 0, 0);\n"
"    \n"
"    background-color: rgb(95, 234, 255);\n"
"}\n"
"QPushButton{\n"
"    \n"
"    \n"
"    \n"
"    background-color: rgb(242, 248, 252);\n"
"    \n"
"    color: rgb(0, 0, 0);\n"
"}")
        self.Dot.setObjectName("Dot")
        self.gridLayout.addWidget(self.Dot, 6, 1, 1, 1)
        self.Total = QtWidgets.QPushButton(parent=self.centralwidget)
        sizePolicy = QtWidgets.QSizePolicy(QtWidgets.QSizePolicy.Policy.MinimumExpanding, QtWidgets.QSizePolicy.Policy.Preferred)
        sizePolicy.setHorizontalStretch(0)
        sizePolicy.setVerticalStretch(10)
        sizePolicy.setHeightForWidth(self.Total.sizePolicy().hasHeightForWidth())
        self.Total.setSizePolicy(sizePolicy)
        self.Total.setStyleSheet("QPushButton{\n"
"font: 75 25pt \"Segoe UI Variable Text\";\n"
"    color: rgb(255, 255, 255);\n"
"    \n"
"    background-color: rgb(81, 70, 25);\n"
"border-radius:18px;\n"
"}\n"
"QPushButton:hover{\n"
"color: rgb(0, 0, 0);\n"
"    \n"
"    background-color: rgb(95, 234, 255);\n"
"}\n"
"QPushButton{\n"
"    \n"
"    \n"
"    background-color: rgb(82, 201, 220);\n"
"    \n"
"    color: rgb(0, 0, 0);\n"
"}")
        self.Total.setObjectName("Total")
        self.gridLayout.addWidget(self.Total, 6, 2, 1, 1)
        self.Plus = QtWidgets.QPushButton(parent=self.centralwidget)
        sizePolicy = QtWidgets.QSizePolicy(QtWidgets.QSizePolicy.Policy.MinimumExpanding, QtWidgets.QSizePolicy.Policy.Preferred)
        sizePolicy.setHorizontalStretch(0)
        sizePolicy.setVerticalStretch(10)
        sizePolicy.setHeightForWidth(self.Plus.sizePolicy().hasHeightForWidth())
        self.Plus.setSizePolicy(sizePolicy)
        self.Plus.setStyleSheet("QPushButton{\n"
"font: 75 25pt \"Segoe UI Variable Text\";\n"
"    color: rgb(255, 255, 255);\n"
"    \n"
"    background-color: rgb(81, 70, 25);\n"
"border-radius:18px;\n"
"}\n"
"QPushButton:hover{\n"
"color: rgb(0, 0, 0);\n"
"    \n"
"    background-color: rgb(95, 234, 255);\n"
"}\n"
"QPushButton{\n"
"    \n"
"    \n"
"    background-color: rgb(82, 201, 220);\n"
"    \n"
"    color: rgb(0, 0, 0);\n"
"}")
        self.Plus.setObjectName("Plus")
        self.gridLayout.addWidget(self.Plus, 5, 3, 2, 1)
        self.Minus = QtWidgets.QPushButton(parent=self.centralwidget)
        sizePolicy = QtWidgets.QSizePolicy(QtWidgets.QSizePolicy.Policy.MinimumExpanding, QtWidgets.QSizePolicy.Policy.Preferred)
        sizePolicy.setHorizontalStretch(0)
        sizePolicy.setVerticalStretch(10)
        sizePolicy.setHeightForWidth(self.Minus.sizePolicy().hasHeightForWidth())
        self.Minus.setSizePolicy(sizePolicy)
        self.Minus.setStyleSheet("QPushButton{\n"
"font: 75 25pt \"Segoe UI Variable Text\";\n"
"    color: rgb(255, 255, 255);\n"
"    \n"
"    background-color: rgb(81, 70, 25);\n"
"border-radius:18px;\n"
"}\n"
"QPushButton:hover{\n"
"color: rgb(0, 0, 0);\n"
"    \n"
"    background-color: rgb(95, 234, 255);\n"
"}\n"
"QPushButton{\n"
"    \n"
"    \n"
"    background-color: rgb(82, 201, 220);\n"
"    \n"
"    color: rgb(0, 0, 0);\n"
"}")
        self.Minus.setObjectName("Minus")
        self.gridLayout.addWidget(self.Minus, 3, 3, 1, 1)
        self.Divison = QtWidgets.QPushButton(parent=self.centralwidget)
        sizePolicy = QtWidgets.QSizePolicy(QtWidgets.QSizePolicy.Policy.MinimumExpanding, QtWidgets.QSizePolicy.Policy.Preferred)
        sizePolicy.setHorizontalStretch(0)
        sizePolicy.setVerticalStretch(10)
        sizePolicy.setHeightForWidth(self.Divison.sizePolicy().hasHeightForWidth())
        self.Divison.setSizePolicy(sizePolicy)
        self.Divison.setStyleSheet("QPushButton{\n"
"font: 75 25pt \"Segoe UI Variable Text\";\n"
"    color: rgb(255, 255, 255);\n"
"    \n"
"    background-color: rgb(81, 70, 25);\n"
"border-radius:18px;\n"
"}\n"
"QPushButton:hover{\n"
"color: rgb(0, 0, 0);\n"
"    \n"
"    background-color: rgb(95, 234, 255);\n"
"}\n"
"QPushButton{\n"
"    \n"
"    \n"
"    background-color: rgb(82, 201, 220);\n"
"    \n"
"    color: rgb(0, 0, 0);\n"
"}")
        self.Divison.setObjectName("Divison")
        self.gridLayout.addWidget(self.Divison, 2, 3, 1, 1)
        self.Multiplye = QtWidgets.QPushButton(parent=self.centralwidget)
        sizePolicy = QtWidgets.QSizePolicy(QtWidgets.QSizePolicy.Policy.MinimumExpanding, QtWidgets.QSizePolicy.Policy.Preferred)
        sizePolicy.setHorizontalStretch(0)
        sizePolicy.setVerticalStretch(10)
        sizePolicy.setHeightForWidth(self.Multiplye.sizePolicy().hasHeightForWidth())
        self.Multiplye.setSizePolicy(sizePolicy)
        self.Multiplye.setStyleSheet("QPushButton{\n"
"font: 75 21pt \"Segoe UI Variable Text\";\n"
"    color: rgb(255, 255, 255);\n"
"    \n"
"    background-color: rgb(81, 70, 25);\n"
"border-radius:18px;\n"
"}\n"
"QPushButton:hover{\n"
"color: rgb(0, 0, 0);\n"
"    \n"
"    background-color: rgb(95, 234, 255);\n"
"}\n"
"QPushButton{\n"
"    \n"
"    \n"
"    background-color: rgb(82, 201, 220);\n"
"    \n"
"    color: rgb(0, 0, 0);\n"
"}")
        self.Multiplye.setObjectName("Multiplye")
        self.gridLayout.addWidget(self.Multiplye, 1, 3, 1, 1)
        self.Del = QtWidgets.QPushButton(parent=self.centralwidget)
        sizePolicy = QtWidgets.QSizePolicy(QtWidgets.QSizePolicy.Policy.MinimumExpanding, QtWidgets.QSizePolicy.Policy.Preferred)
        sizePolicy.setHorizontalStretch(0)
        sizePolicy.setVerticalStretch(10)
        sizePolicy.setHeightForWidth(self.Del.sizePolicy().hasHeightForWidth())
        self.Del.setSizePolicy(sizePolicy)
        self.Del.setStyleSheet("QPushButton{\n"
"font: 75 20pt \"Segoe UI Variable Text\";\n"
"    color: rgb(255, 255, 255);\n"
"    \n"
"    background-color: rgb(81, 70, 25);\n"
"border-radius:18px;\n"
"}\n"
"QPushButton:hover{\n"
"color: rgb(0, 0, 0);\n"
"    \n"
"    background-color: rgb(95, 234, 255);\n"
"}\n"
"QPushButton{\n"
"    \n"
"    \n"
"    background-color: rgb(82, 201, 220);\n"
"    \n"
"    color: rgb(0, 0, 0);\n"
"}")
        self.Del.setObjectName("Del")
        self.gridLayout.addWidget(self.Del, 1, 2, 1, 1)
        self.Clear = QtWidgets.QPushButton(parent=self.centralwidget)
        sizePolicy = QtWidgets.QSizePolicy(QtWidgets.QSizePolicy.Policy.MinimumExpanding, QtWidgets.QSizePolicy.Policy.Preferred)
        sizePolicy.setHorizontalStretch(0)
        sizePolicy.setVerticalStretch(10)
        sizePolicy.setHeightForWidth(self.Clear.sizePolicy().hasHeightForWidth())
        self.Clear.setSizePolicy(sizePolicy)
        self.Clear.setStyleSheet("QPushButton{\n"
"font: 75 20pt \"Segoe UI Variable Text\";\n"
"    color: rgb(255, 255, 255);\n"
"    \n"
"    background-color: rgb(81, 70, 25);\n"
"border-radius:18px;\n"
"}\n"
"QPushButton:hover{\n"
"color: rgb(0, 0, 0);\n"
"    \n"
"    background-color: rgb(95, 234, 255);\n"
"}\n"
"QPushButton{\n"
"    \n"
"    \n"
"    background-color: rgb(82, 201, 220);\n"
"    \n"
"    color: rgb(0, 0, 0);\n"
"}")
        self.Clear.setObjectName("Clear")
        self.gridLayout.addWidget(self.Clear, 1, 0, 1, 2)
        self.verticalLayout.addLayout(self.gridLayout)
        MainWindow.setCentralWidget(self.centralwidget)
        self.menubar = QtWidgets.QMenuBar(parent=MainWindow)
        self.menubar.setGeometry(QtCore.QRect(0, 0, 443, 26))
        self.menubar.setObjectName("menubar")
        MainWindow.setMenuBar(self.menubar)
        self.statusbar = QtWidgets.QStatusBar(parent=MainWindow)
        self.statusbar.setObjectName("statusbar")
        MainWindow.setStatusBar(self.statusbar)

        self.retranslateUi(MainWindow)
        QtCore.QMetaObject.connectSlotsByName(MainWindow)

        self.pushButton.clicked.connect(self.method_1)
        self.push_2.clicked.connect(self.method_2)
        self.push_3.clicked.connect(self.method_3)
        self.push_4.clicked.connect(self.method_4)
        self.push_5.clicked.connect(self.method_5)
        self.push_6.clicked.connect(self.method_6)
        self.push_7.clicked.connect(self.method_7)
        self.push_8.clicked.connect(self.method_8)
        self.push_9.clicked.connect(self.method_9)
        self.push_0.clicked.connect(self.method_0)
        self.Dot.clicked.connect(self.method_Dot)
        self.Clear.clicked.connect(self.method_Clear)
        self.Del.clicked.connect(self.method_Del)
        self.Multiplye.clicked.connect(self.method_Multiplye)
        self.Divison.clicked.connect(self.method_Divison)
        self.Minus.clicked.connect(self.method_Minus)
        self.Plus.clicked.connect(self.method_Plus)
        self.Total.clicked.connect(self.method_Total)

    def method_1(self):
        text=self.label.text()
        self.label.setText(text+"1")

    def method_2(self):
        text=self.label.text()
        self.label.setText(text+"2")

    def method_3(self):
        text=self.label.text()
        self.label.setText(text+"3")

    def method_4(self):
        text=self.label.text()
        self.label.setText(text+"4")

    def method_5(self):
        text=self.label.text()
        self.label.setText(text+"5")

    def method_6(self):
        text=self.label.text()
        self.label.setText(text+"6")

    def method_7(self):
        text=self.label.text()
        self.label.setText(text+"7")

    def method_8(self):
        text=self.label.text()
        self.label.setText(text+"8")

    def method_9(self):
        text=self.label.text()
        self.label.setText(text+"9")

    def method_0(self):
        text=self.label.text()
        self.label.setText(text+"0")


    def method_Dot(self):
        text=self.label.text()
        self.label.setText(text+".")

    def method_Multiplye(self):
        text=self.label.text()
        self.label.setText(text+"*")

    def method_Divison(self):
        text=self.label.text()
        self.label.setText(text+"/")

    def method_Minus(self):
        text=self.label.text()
        self.label.setText(text+"-")

    def method_Plus(self):
        text=self.label.text()
        self.label.setText(text+"+")

    def method_Clear(self):
        self.label.setText("")

    def method_Del(self):
        text=self.label.text()
        self.label.setText(text[:len(text)-1])

    def method_Total(self):
        text=self.label.text()

        try:
            ans=eval(text)
            self.label.setText(str(ans))

        except:
            self.label.setText("Worng Input")



    def retranslateUi(self, MainWindow):
        _translate = QtCore.QCoreApplication.translate
        MainWindow.setWindowTitle(_translate("MainWindow", "Calculator"))
        self.push_9.setText(_translate("MainWindow", "9"))
        self.push_8.setText(_translate("MainWindow", "8"))
        self.push_4.setText(_translate("MainWindow", "4"))
        self.push_5.setText(_translate("MainWindow", "5"))
        self.push_2.setText(_translate("MainWindow", "2"))
        self.push_3.setText(_translate("MainWindow", "3"))
        self.push_7.setText(_translate("MainWindow", "7"))
        self.push_6.setText(_translate("MainWindow", "6"))
        self.pushButton.setText(_translate("MainWindow", "1"))
        self.label.setText(_translate("MainWindow", ""))
        self.push_0.setText(_translate("MainWindow", "0"))
        self.Dot.setText(_translate("MainWindow", "."))
        self.Total.setText(_translate("MainWindow", "="))
        self.Plus.setText(_translate("MainWindow", "+"))
        self.Minus.setText(_translate("MainWindow", "-"))
        self.Divison.setText(_translate("MainWindow", "÷"))
        self.Multiplye.setText(_translate("MainWindow", "X"))
        self.Del.setText(_translate("MainWindow", "Del"))
        self.Clear.setText(_translate("MainWindow", "Clear"))


if __name__ == "__main__":
    import sys
    app = QtWidgets.QApplication(sys.argv)
    MainWindow = QtWidgets.QMainWindow()
    ui = Ui_MainWindow()
    ui.setupUi(MainWindow)
    MainWindow.show()
    sys.exit(app.exec())
# Out:
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 0
# C:\Users\Pradeep\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py:3585: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)
